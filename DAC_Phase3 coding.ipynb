# %%
#imports necessary libraries to do basic things on the dataset
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt


print('Successfully imported')
# Out:
# Successfully imported

# %%
#Reading data
data = pd.read_csv('project2.csv')
data.head(30)
# Out:
#            Timestamp  Timestamp.1 Timestamp.2     Timestamp.3 state  \
# 0   27-08-2014 11:29           37      Female   United States    IL
# 1   27-08-2014 11:29           44           M   United States    IN
# 2   27-08-2014 11:29           32        Male          Canada   NaN
# 3   27-08-2014 11:29           31        Male  United Kingdom   NaN
# 4   27-08-2014 11:30           31        Male   United States    TX
# 5   27-08-2014 11:31           33        Male   United States    TN
# 6   27-08-2014 11:31           35      Female   United States    MI
# 7   27-08-2014 11:32           39           M          Canada   NaN
# 8   27-08-2014 11:32           42      Female   United States    IL
# 9   27-08-2014 11:32           23        Male          Canada   NaN
# 10  27-08-2014 11:32           31        Male   United States    OH
# 11  27-08-2014 11:32           29        male        Bulgaria   NaN
# 12  27-08-2014 11:33           42      female   United States    CA
# 13  27-08-2014 11:33           36        Male   United States    CT
# 14  27-08-2014 11:33           27        Male          Canada   NaN
# 15  27-08-2014 11:34           29      female   United States    IL
# 16  27-08-2014 11:34           23        Male  United Kingdom   NaN
# 17  27-08-2014 11:34           32        Male   United States    TN
# 18  27-08-2014 11:34           46        male   United States    MD
# 19  27-08-2014 11:35           36        Male          France   NaN
# 20  27-08-2014 11:35           29        Male   United States    NY
# 21  27-08-2014 11:35           31        male   United States    NC
# 22  27-08-2014 11:35           46        Male   United States    MA
# 23  27-08-2014 11:36           41        Male   United States    IA
# 24  27-08-2014 11:36           33        male   United States    CA
# 25  27-08-2014 11:37           35        male   United States    TN
# 26  27-08-2014 11:37           33        male   United States    TN
# 27  27-08-2014 11:37           35      Female   United States    CA
# 28  27-08-2014 11:38           34        male   United States    OH
# 29  27-08-2014 11:38           37        Male  United Kingdom   NaN
#
#    self_employed family_history treatment work_interfere    no_employees  ...  \
# 0            NaN             No       Yes          Often          Jun-25  ...
# 1            NaN             No        No         Rarely  More than 1000  ...
# 2            NaN             No        No         Rarely          Jun-25  ...
# 3            NaN            Yes       Yes          Often          26-100  ...
# 4            NaN             No        No          Never         100-500  ...
# 5            NaN            Yes        No      Sometimes          Jun-25  ...
# 6            NaN            Yes       Yes      Sometimes          01-May  ...
# 7            NaN             No        No          Never          01-May  ...
# 8            NaN            Yes       Yes      Sometimes         100-500  ...
# 9            NaN             No        No          Never          26-100  ...
# 10           NaN             No       Yes      Sometimes          Jun-25  ...
# 11           NaN             No        No          Never         100-500  ...
# 12           NaN            Yes       Yes      Sometimes          26-100  ...
# 13           NaN            Yes        No          Never        500-1000  ...
# 14           NaN             No        No          Never          Jun-25  ...
# 15           NaN            Yes       Yes         Rarely          26-100  ...
# 16           NaN             No       Yes      Sometimes          26-100  ...
# 17           NaN             No       Yes      Sometimes          Jun-25  ...
# 18           Yes            Yes        No      Sometimes          01-May  ...
# 19           Yes            Yes        No            NaN          Jun-25  ...
# 20            No            Yes       Yes      Sometimes         100-500  ...
# 21           Yes             No        No          Never          01-May  ...
# 22            No             No       Yes          Often          26-100  ...
# 23            No             No       Yes          Never  More than 1000  ...
# 24            No            Yes       Yes         Rarely          26-100  ...
# 25            No            Yes       Yes      Sometimes  More than 1000  ...
# 26            No             No        No            NaN          01-May  ...
# 27            No            Yes       Yes         Rarely          Jun-25  ...
# 28            No             No       Yes      Sometimes          26-100  ...
# 29            No             No        No      Sometimes          Jun-25  ...
#
#                  leave mental_health_consequence phys_health_consequence  \
# 0        Somewhat easy                        No                      No
# 1           Don't know                     Maybe                      No
# 2   Somewhat difficult                        No                      No
# 3   Somewhat difficult                       Yes                     Yes
# 4           Don't know                        No                      No
# 5           Don't know                        No                      No
# 6   Somewhat difficult                     Maybe                   Maybe
# 7           Don't know                        No                      No
# 8       Very difficult                     Maybe                      No
# 9           Don't know                        No                      No
# 10          Don't know                        No                      No
# 11          Don't know                        No                      No
# 12  Somewhat difficult                       Yes                     Yes
# 13          Don't know                        No                      No
# 14       Somewhat easy                        No                      No
# 15       Somewhat easy                        No                      No
# 16           Very easy                     Maybe                      No
# 17          Don't know                     Maybe                      No
# 18           Very easy                        No                      No
# 19       Somewhat easy                        No                      No
# 20  Somewhat difficult                     Maybe                      No
# 21  Somewhat difficult                        No                      No
# 22          Don't know                     Maybe                      No
# 23          Don't know                     Maybe                      No
# 24          Don't know                        No                      No
# 25           Very easy                       Yes                      No
# 26          Don't know                     Maybe                   Maybe
# 27          Don't know                        No                      No
# 28  Somewhat difficult                        No                      No
# 29      Very difficult                       Yes                   Maybe
#
#        coworkers    supervisor mental_health_interview phys_health_interview  \
# 0   Some of them           Yes                      No                 Maybe
# 1             No            No                      No                    No
# 2            Yes           Yes                     Yes                   Yes
# 3   Some of them            No                   Maybe                 Maybe
# 4   Some of them           Yes                     Yes                   Yes
# 5            Yes           Yes                      No                 Maybe
# 6   Some of them            No                      No                    No
# 7             No            No                      No                    No
# 8            Yes           Yes                      No                 Maybe
# 9            Yes           Yes                   Maybe                 Maybe
# 10  Some of them           Yes                      No                    No
# 11           Yes           Yes                     Yes                   Yes
# 12           Yes           Yes                   Maybe                 Maybe
# 13           Yes           Yes                      No                    No
# 14  Some of them  Some of them                   Maybe                   Yes
# 15           Yes  Some of them                   Maybe                 Maybe
# 16  Some of them            No                   Maybe                 Maybe
# 17  Some of them           Yes                      No                    No
# 18           Yes           Yes                      No                   Yes
# 19  Some of them  Some of them                   Maybe                 Maybe
# 20  Some of them  Some of them                      No                    No
# 21  Some of them  Some of them                      No                 Maybe
# 22  Some of them           Yes                      No                 Maybe
# 23            No            No                      No                   Yes
# 24           Yes           Yes                      No                   Yes
# 25  Some of them           Yes                      No                   Yes
# 26  Some of them            No                      No                    No
# 27           Yes           Yes                   Maybe                 Maybe
# 28  Some of them            No                      No                    No
# 29  Some of them            No                      No                 Maybe
#
#    mental_vs_physical obs_consequence  \
# 0                 Yes              No
# 1          Don't know              No
# 2                  No              No
# 3                  No             Yes
# 4          Don't know              No
# 5          Don't know              No
# 6          Don't know              No
# 7                  No              No
# 8                  No              No
# 9                 Yes              No
# 10         Don't know              No
# 11         Don't know              No
# 12                 No             Yes
# 13         Don't know              No
# 14                Yes              No
# 15         Don't know              No
# 16                 No              No
# 17                 No              No
# 18                Yes             Yes
# 19         Don't know              No
# 20                 No              No
# 21                Yes              No
# 22                 No              No
# 23         Don't know              No
# 24         Don't know              No
# 25                 No              No
# 26         Don't know              No
# 27                Yes              No
# 28                 No              No
# 29                 No              No
#
#                                              comments
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  I'm not on my company's health insurance which...
# 14                                                NaN
# 15  I have chronic low-level neurological issues t...
# 16  My company does provide healthcare but not to ...
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                Relatively new job. Ask again later
# 25  Sometimes I think  about using drugs for my me...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
# [30 rows x 27 columns]

# %%
df = pd.read_csv("project2.csv")

# %%
df.shape
# Out:
# (41, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 27 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Timestamp                  41 non-null     object
#  1   Timestamp.1                41 non-null     int64
#  2   Timestamp.2                41 non-null     object
#  3   Timestamp.3                41 non-null     object
#  4   state                      27 non-null     object
#  5   self_employed              23 non-null     object
#  6   family_history             41 non-null     object
#  7   treatment                  41 non-null     object
#  8   work_interfere             37 non-null     object
#  9   no_employees               41 non-null     object
#  10  remote_work                41 non-null     object
#  11  tech_company               41 non-null     object
#  12  benefits                   41 non-null     object
#  13  care_options               41 non-null     object
#  14  wellness_program           41 non-null     object
#  15  seek_help                  41 non-null     object
#  16  anonymity                  41 non-null     object
#  17  leave                      41 non-null     object
#  18  mental_health_consequence  41 non-null     object
#  19  phys_health_consequence    41 non-null     object
#  20  coworkers                  41 non-null     object
#  21  supervisor                 41 non-null     object
#  22  mental_health_interview    41 non-null     object
#  23  phys_health_interview      41 non-null     object
#  24  mental_vs_physical         41 non-null     object
#  25  obs_consequence            41 non-null     object
#  26  comments                   6 non-null      object
# dtypes: int64(1), object(26)
# memory usage: 8.8+ KB

# %%
df.isna().sum()
# Out:
# Timestamp                     0
# Timestamp.1                   0
# Timestamp.2                   0
# Timestamp.3                   0
# state                        14
# self_employed                18
# family_history                0
# treatment                     0
# work_interfere                4
# no_employees                  0
# remote_work                   0
# tech_company                  0
# benefits                      0
# care_options                  0
# wellness_program              0
# seek_help                     0
# anonymity                     0
# leave                         0
# mental_health_consequence     0
# phys_health_consequence       0
# coworkers                     0
# supervisor                    0
# mental_health_interview       0
# phys_health_interview         0
# mental_vs_physical            0
# obs_consequence               0
# comments                     35
# dtype: int64

# %%
self_employed_percent = (df["self_employed"].isnull().sum()/len(df["self_employed"]))*100
work_interfere_percent = (df["work_interfere"].isnull().sum()/len(df["work_interfere"]))*100

print(f"The percentage of missing values in self_employed column is {round(self_employed_percent, 2)}%")
print(f"The percentage of missing values in work_interfere column is {round(work_interfere_percent, 2)}%")
# Out:
# The percentage of missing values in self_employed column is 43.9%
# The percentage of missing values in work_interfere column is 9.76%

# %%
df["self_employed"] = df["self_employed"].fillna(df["self_employed"].mode()[0])

df["work_interfere"] = df["work_interfere"].fillna(df["work_interfere"].mode()[0])

# %%
df.head()
# Out:
#           Timestamp  Timestamp.1 Timestamp.2     Timestamp.3 state  \
# 0  27-08-2014 11:29           37      Female   United States    IL
# 1  27-08-2014 11:29           44           M   United States    IN
# 2  27-08-2014 11:29           32        Male          Canada   NaN
# 3  27-08-2014 11:29           31        Male  United Kingdom   NaN
# 4  27-08-2014 11:30           31        Male   United States    TX
#
#   self_employed family_history treatment work_interfere    no_employees  ...  \
# 0            No             No       Yes          Often          Jun-25  ...
# 1            No             No        No         Rarely  More than 1000  ...
# 2            No             No        No         Rarely          Jun-25  ...
# 3            No            Yes       Yes          Often          26-100  ...
# 4            No             No        No          Never         100-500  ...
#
#                 leave mental_health_consequence phys_health_consequence  \
# 0       Somewhat easy                        No                      No
# 1          Don't know                     Maybe                      No
# 2  Somewhat difficult                        No                      No
# 3  Somewhat difficult                       Yes                     Yes
# 4          Don't know                        No                      No
#
#       coworkers supervisor mental_health_interview phys_health_interview  \
# 0  Some of them        Yes                      No                 Maybe
# 1            No         No                      No                    No
# 2           Yes        Yes                     Yes                   Yes
# 3  Some of them         No                   Maybe                 Maybe
# 4  Some of them        Yes                     Yes                   Yes
#
#   mental_vs_physical obs_consequence comments
# 0                Yes              No      NaN
# 1         Don't know              No      NaN
# 2                 No              No      NaN
# 3                 No             Yes      NaN
# 4         Don't know              No      NaN
#
# [5 rows x 27 columns]

# %%
df.drop(["state", "comments"], axis=1, inplace=True)

# %%
df.isna().sum()
# Out:
# Timestamp                    0
# Timestamp.1                  0
# Timestamp.2                  0
# Timestamp.3                  0
# self_employed                0
# family_history               0
# treatment                    0
# work_interfere               0
# no_employees                 0
# remote_work                  0
# tech_company                 0
# benefits                     0
# care_options                 0
# wellness_program             0
# seek_help                    0
# anonymity                    0
# leave                        0
# mental_health_consequence    0
# phys_health_consequence      0
# coworkers                    0
# supervisor                   0
# mental_health_interview      0
# phys_health_interview        0
# mental_vs_physical           0
# obs_consequence              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Timestamp', 'Timestamp.1', 'Timestamp.2', 'Timestamp.3',
#        'self_employed', 'family_history', 'treatment', 'work_interfere',
#        'no_employees', 'remote_work', 'tech_company', 'benefits',
#        'care_options', 'wellness_program', 'seek_help', 'anonymity', 'leave',
#        'mental_health_consequence', 'phys_health_consequence', 'coworkers',
#        'supervisor', 'mental_health_interview', 'phys_health_interview',
#        'mental_vs_physical', 'obs_consequence'],
#       dtype='object')

# %%
plt.figure(figsize=(17,5))
ax = sns.countplot(x='Timestamp.3', data=df)

ax.set_xticklabels(
    ax.get_xticklabels(), 
    rotation=45, 
    horizontalalignment='right'    
)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()+0.25, p.get_height()+0.01), ha='center')

# %%
min_age = df["Timestamp.1"].min()
max_age = df["Timestamp.1"].max()
mean_age = df["Timestamp.1"].mean()
median_age = df["Timestamp.1"].median()

print(f"Min: {min_age}, \nMax: {max_age}, \nMean: {mean_age}, \nMedian: {median_age}")
# Out:
# Min: 23,
# Max: 50,
# Mean: 34.390243902439025,
# Median: 33.0

# %%
df["Timestamp.1"].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24], dtype=int64)

# %%
negative_age = (df["Timestamp.1"]<0).sum()
over_age = (df["Timestamp.1"]>80).sum()

print(f"Number of negative age entries: {negative_age}\nNumber of overage: {over_age}")
# Out:
# Number of negative age entries: 0
# Number of overage: 0

# %%
df["Timestamp.1"].unique()
# Out:
# array([37, 44, 32, 31, 33, 35, 39, 42, 23, 29, 36, 27, 46, 41, 34, 30, 40,
#        38, 50, 24], dtype=int64)

# %%
df["Timestamp.1"].hist()
# Out:
# <Axes: >

# %%
sns.boxplot(x=df["Timestamp.1"])
# Out:
# <Axes: xlabel='Timestamp.1'>

# %%
sns.boxplot(x=df["Timestamp.1"])
